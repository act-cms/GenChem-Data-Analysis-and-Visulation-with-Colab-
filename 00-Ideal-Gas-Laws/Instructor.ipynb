# %% [markdown]
# # Overview
# This module is designed to introduce students to use Google Colab, Gemini, and Python programming language to read, interpret, and analyze provided data for a sample of ideal gas.
#
# Written by Dr. Linlin Jensen
#
# > **AI Use Disclaimer:** Microsoft Copilot was used to improve clarity and organization of the activity’s written instructions.
#
# ### Learning Objectives
# By the end of this recitation, you will be able to:
# * Scientific Skills
#   - **Data Interpretation:** Analyze how volume changes with temperature from a data table.
#   - **Graphical Representation:** Construct a volume vs. temperature graph and interpret the meaning of the slope and intercepts.
#   - **Mathematical Modeling:** Derive the mathematical relationship from the graph and data. Describe the relationship between volume and temperature and connect it to the Ideal Gas Law, PV = nRT.
#
# * Cyberinfrastructure Skills
#   - **Data Handling:** Import and load a CSV file into a Pandas DataFrame.
#   - Access and open a notebook in Google Colab
#   - Identify and use the key components of the Google Colab interface (code cells, text cells, run button).
#   - Read and understand a Python script with comments.
#   - Run a Python script and interpret its output.
#   - **Data Cleaning/Transformation:** Create a new column by converting Celsius to Kelvin.
#   - **Data Visualization:** Generate a scatter plot and a linear regression line using Python libraries (e.g., Pandas, Matplotlib, NumPy/SciPy).
#   - **Computational Analysis:** Perform a linear fit to find the slope and intercept.
#   - **AI Literacy:** Formulate effective and specific prompts to get the most out of an AI assistant.

# %% [markdown]
# # Getting Started

# %% [markdown]
# ## Step 1: Download Relevant Files and Access Google Colab
#
# 1. Download the files "Intro_recitation_gas_law_student.ipynb" and "gas_law_simulated_data.csv" from your recitation Canvas course site. Once downloaded, these files will most likely be stored in the Download folder of your local computer.
#
# 2.   Open your web browser and go to https://colab.research.google.com/.
#
# 3.   Log in with your Google account. This is the same account you use for Gmail, Google Drive, etc. If you don't have one, you'll need to create a free account.

# %% [markdown]
# ## Step 2: Open a Notebook
#
# Once you're on the Colab homepage, click "File" > "Open notebook": This will open a window with several tabs:
#
# - "Recent": Lists recently opened Colab files.
#
# - "Google Drive": Allows you to browse your Google Drive folders to select a notebook.
#
# - "Github": Allows you to open a notebook directly from a GitHub repository (requires the URL or repository details).
#
# - "Upload": Allows you to upload a .ipynb file from your local computer. You can drag and drop the file here or click "Browse", locate the notebook on your machine, and click "Open".
#
# **Use the "Upload" option to open the "Intro_recitation_gas_law_student.ipynb" file.**

# %% [markdown]
# ## Step 3: Tour the Interface
#
# You should now see a Colab notebook. Here are the key parts you'll be using:
#
# - Code Cells: These are the gray boxes where you'll write and run your code. You can add a new one by clicking on "+ Code" at the top of the notebook.
#
# - Text Cells: These are for adding notes, explanations, and instructions. You can add a new one by clicking on "+ Text" at the top of the notebook.
#
# - Run Button: To run a code cell, click the "play" button (a triangle) on the left side of the cell, or press Shift + Enter on your keyboard.

# %% [markdown]
# ## Step 4: Upload the Experimental Data to Colab Worksheet
#
# To achieve this, following the steps below:
# 1. Make sure that you have downloaded the file "gas_law_simulated_data.csv" from your recitation Canvas course site. *This file contains a series of volume measurement at different temperatures for a 0.25 mole sample of ideal gas, recorded at a constant temperature*.
# 2. Click on the file explorer icon on the left sidebar
# 3. Drag and drop the file to the sidebar. A window will pop out and give you a Warning: **Ensure that your files are saved elsewhere. This runtime's files will be deleted when this runtime is terminated.** This means that the file will only be temporarily stored in the folder. Once you close the notebook, the file will be deleted and disappear.
# 4. Click on "Okay" and the file should appear below the folder titled "sample_data".

# %% [markdown]
# ## Step 5: Read the data:
# To achieve this, following the steps below:
# 1. click on "+ Code" below, a code cell will appear
# 2. Click on <u>generate</u> with AI
# 3. Paste the following prompt: "**Read in the data from the csv file.**"
# 4. After a moment, you should see the code in the code cell, highlighted in green. Additionally, you'll see the response in Gemini with options: "Accept & Run", "Accept", or "Cancel".
# 5. Click the "Accept & Run" button to run the cell.
#
# > After a moment, you should see the temperature and volume data from the file printed right below the code cell. **Ignore the prompts suggested by Gemini for now.** Inspect the data table and answer the questions in your recitation worksheet.

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('gas_law_simulated_data.csv')

# Display the first 5 rows of the DataFrame
# display(df.head())

# Display all rows of the DataFrame
display(df)
# Out:
#    T (°C)  V (mL)
# 0       0   107.9
# 1      10   111.7
# 2      20   115.5
# 3      30   119.4
# 4      40   123.2
# 5      50   127.0

# %% [markdown]
# ## Step 6: Initial plot of data
#
# To achieve this, following the steps below:
# 1. click on "+ Code" below, a code cell will appear
# 2. Click on <u>generate</u> with AI
# 3. Paste the following prompt: "**Plot the volume as a function of temperature. Perform a linear regression on the data. Add the linear regression line to the plot.**"
# 4. After a momnet, you should see the code in the code cell, highlighted in green. Additionally, you'll see the response in Gemini with options: "Accept & Run", "Accept", or "Cancel".
# 5. Click the "Accept & Run" button to run the cell.
#
# > After a moment, you should see a plot with volume on the y-axis and temperature (in &#8451;) on the x-axis. **Right click on the image, copy and past it to your recitation worksheet, and answer the relevant questions.**

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Create a scatter plot of Volume vs. Temperature (°C)
plt.figure(figsize=(8, 6))
plt.scatter(df['T (°C)'], df['V (mL)'], label='Data')

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(df['T (°C)'], df['V (mL)'])

# Calculate the values for the regression line
temp_celsius = np.array(df['T (°C)'])
volume_predicted = slope * temp_celsius + intercept

# Add the linear regression line to the plot
plt.plot(temp_celsius, volume_predicted, color='red', label=f'Linear Fit (Slope={slope:.2f}, Intercept={intercept:.2f})')

plt.xlabel('Temperature (°C)')
plt.ylabel('Volume (mL)')
plt.title('Volume vs. Temperature (°C) with Linear Fit')
plt.grid(True)
plt.legend()

# Save the plot as a PNG file
plt.savefig('volume_vs_temperature_celsius.png')

plt.show()

# Print the linear regression results
print(f"Linear Regression Results (Celsius):")
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")
print(f"R-squared: {r_value**2:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Standard Error: {std_err:.4f}")
# Out:
# Linear Regression Results (Celsius):
# Slope: 0.38
# Intercept: 107.89
# R-squared: 1.00
# P-value: 0.0000
# Standard Error: 0.0007

# %% [markdown]
# Given the Ideal Gas Law: $$PV=nRT$$ We can rearrange the equation and express the relationship between volume and temperature as: $$V= \left(\frac{nR}{P}\right)T = kT$$ <br>
# This means if we plot $V$ as a function of $T$, we should expect a **linear line with a slope of $k = \frac{nR}{P}$ and y-intercept = $0$**.

# %% [markdown]
# ## Step 7: Data Transformation
#
# To achieve this, following the steps below:
# 1. click on "+ Code" below, a code cell will appear
# 2. Click on <u>generate</u> with AI
# 3. Paste the following prompt: "**Convert temperature to Kelvin. Plot volume as a function of temperature in Kelvin. Perform a linear regression on the data. Add the linear regression line to the plot.**"
# 4. After a momnet, you should see the code in the code cell, highlighted in green. Additionally, you'll see the response in Gemini with options: "Accept & Run", "Accept", or "Cancel".
# 5. Click the "Accept & Run" button to run the cell.
#
# > After a moment, you should see a plot with volume on the y-axis and temperature (in $K$) on the x-axis. **Right click on the image, copy and paste it into your recitation worksheet, and answer the relevant questions.**

# %%
# Convert temperature from Celsius to Kelvin
df['T (K)'] = df['T (°C)'] + 273.15

# Create a scatter plot of Volume vs. Temperature (K)
plt.figure(figsize=(8, 6))
plt.scatter(df['T (K)'], df['V (mL)'], label='Data')

# Perform linear regression on the data in Kelvin
slope_k, intercept_k, r_value_k, p_value_k, std_err_k = linregress(df['T (K)'], df['V (mL)'])

# Calculate the values for the regression line in Kelvin
temp_kelvin = np.array(df['T (K)'])
volume_predicted_k = slope_k * temp_kelvin + intercept_k

# Add the linear regression line to the plot
plt.plot(temp_kelvin, volume_predicted_k, color='red', label=f'Linear Fit (Slope={slope_k:.2f}, Intercept={intercept_k:.2f})')

plt.xlabel('Temperature (K)')
plt.ylabel('Volume (mL)')
plt.title('Volume vs. Temperature (K) with Linear Fit')
plt.grid(True)
plt.legend()

# Save the plot as a PNG file
plt.savefig('volume_vs_temperature_kelvin.png')

plt.show()

# Print the linear regression results for Kelvin
print(f"Linear Regression Results (Kelvin):")
print(f"Slope: {slope_k:.2f}")
print(f"Intercept: {intercept_k:.2f}")
print(f"R-squared: {r_value_k**2:.2f}")
print(f"P-value: {p_value_k:.4f}")
print(f"Standard Error: {std_err_k:.4f}")
# Out:
# Linear Regression Results (Kelvin):
# Slope: 0.38
# Intercept: 3.39
# R-squared: 1.00
# P-value: 0.0000
# Standard Error: 0.0007
